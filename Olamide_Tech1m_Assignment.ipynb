# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv(r"C:\Users\User\Downloads\train1.csv")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11928\42265215.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv(r"C:\Users\User\Downloads\train1.csv")

# %%
train
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
# without promo 2013-01-03
no_promo_in_2013 = train.loc[(train["Promo"]==0) & (train["Date"]=="2013-01-03")]

# %%
no_promo_in_2013
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1013865      1          4  2013-01-03   4327        578     1      0
# 1013866      2          4  2013-01-03   4159        555     1      0
# 1013867      3          4  2013-01-03   5902        721     1      0
# 1013868      4          4  2013-01-03   8247       1248     1      0
# 1013869      5          4  2013-01-03   3465        491     1      0
# ...        ...        ...         ...    ...        ...   ...    ...
# 1014975   1111          4  2013-01-03   4579        444     1      0
# 1014976   1112          4  2013-01-03   8716        809     1      0
# 1014977   1113          4  2013-01-03   5563        718     1      0
# 1014978   1114          4  2013-01-03  18463       3211     1      0
# 1014979   1115          4  2013-01-03   4297        300     1      0
#
#         StateHoliday  SchoolHoliday
# 1013865            0              1
# 1013866            0              1
# ...

# %%
# with promo 2013-01-07
promo_in_2013 = train.loc[(train["Promo"]==1) & (train["Date"]=="2013-01-07")]

# %%
promo_in_2013
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1009405      1          1  2013-01-07   7176        785     1      1
# 1009406      2          1  2013-01-07   6775        763     1      1
# 1009407      3          1  2013-01-07  12247       1079     1      1
# 1009408      4          1  2013-01-07  12112       1562     1      1
# 1009409      5          1  2013-01-07   6978        717     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1010515   1111          1  2013-01-07   9444        735     1      1
# 1010516   1112          1  2013-01-07  25165       1661     1      1
# 1010517   1113          1  2013-01-07   8984        907     1      1
# 1010518   1114          1  2013-01-07  21237       2962     1      1
# 1010519   1115          1  2013-01-07   6905        471     1      1
#
#         StateHoliday  SchoolHoliday
# 1009405            0              1
# 1009406            0              0
# ...

# %%
# total sum of sales and customers without promo 2013-01-03
no_promo_in_2013.groupby("Date").sum().iloc[:,2:4]
# Out:
#               Sales  Customers
# Date
# 2013-01-03  6347820     761040

# %%
a = no_promo_in_2013.groupby("Date").sum().iloc[:,2:4]

# %%
# total sum of sales and customers with promo 2013-01-07
promo_in_2013.groupby("Date").sum().iloc[:,2:4]
# Out:
#                Sales  Customers
# Date
# 2013-01-07  10826848    1058495

# %%
b = promo_in_2013.groupby("Date").sum().iloc[:,2:4]

# %%
combined = pd.concat([a,b])

# %%
combined
# Out:
#                Sales  Customers
# Date
# 2013-01-03   6347820     761040
# 2013-01-07  10826848    1058495

# %%
# bar chart showing the difference(in sales and customers) between 2013-01-03(NO promo) and 2013-01-07(promo)
combined.plot(kind ='bar', linewidth =2.0 )
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
train
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
# without promo 2014-02-14
no_promo_in_2014 = train.loc[(train["Promo"]==0) & (train["Date"]=="2014-02-14")]

# %%
no_promo_in_2014
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 560060      1          5  2014-02-14   4647        591     1      0
# 560061      2          5  2014-02-14   4324        527     1      0
# 560062      3          5  2014-02-14   6213        753     1      0
# 560063      4          5  2014-02-14   8877       1275     1      0
# 560064      5          5  2014-02-14   4431        552     1      0
# ...       ...        ...         ...    ...        ...   ...    ...
# 561170   1111          5  2014-02-14   5833        518     1      0
# 561171   1112          5  2014-02-14   8700        802     1      0
# 561172   1113          5  2014-02-14   6448        751     1      0
# 561173   1114          5  2014-02-14  18630       3183     1      0
# 561174   1115          5  2014-02-14   5966        437     1      0
#
#        StateHoliday  SchoolHoliday
# 560060            0              0
# 560061            0              0
# 560062            0              0
# ...

# %%
# with promo 2014-02-17
promo_in_2014 = train.loc[(train["Promo"]==1) & (train["Date"]=="2014-02-17")]

# %%
promo_in_2014
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 556715      1          1  2014-02-17   5393        606     1      1
# 556716      2          1  2014-02-17   7584        761     1      1
# 556717      3          1  2014-02-17  10020        989     1      1
# 556718      4          1  2014-02-17  11297       1531     1      1
# 556719      5          1  2014-02-17   7170        728     1      1
# ...       ...        ...         ...    ...        ...   ...    ...
# 557825   1111          1  2014-02-17   9066        676     1      1
# 557826   1112          1  2014-02-17  18000       1259     1      1
# 557827   1113          1  2014-02-17   7687        797     1      1
# 557828   1114          1  2014-02-17  21223       3122     1      1
# 557829   1115          1  2014-02-17   7952        517     1      1
#
#        StateHoliday  SchoolHoliday
# 556715            0              0
# 556716            0              1
# 556717            0              0
# ...

# %%
# total sum of sales and customers without promo 2014-02-14
a = no_promo_in_2014.groupby("Date").sum().iloc[:,2:4]

# %%
# total sum of sales and customers with promo 2014-02-17
b = promo_in_2014.groupby("Date").sum().iloc[:,2:4]

# %%
combined = pd.concat([a,b])

# %%
combined
# Out:
#                Sales  Customers
# Date
# 2014-02-14   7086640     840906
# 2014-02-17  10675316    1052877

# %%
# bar chart showing the difference(in sales and customers) between 2013-01-03(NO promo) and 2013-01-07(promo)
combined.plot(kind ='bar', linewidth =2.0 )
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
train
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
# without promo 2015-01-02
no_promo_in_2015 = train.loc[(train["Promo"]==0) & (train["Date"]=="2015-01-02")]

# %%
no_promo_in_2015
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 234150      1          5  2015-01-02   5509        657     1      0
# 234151      2          5  2015-01-02   4137        543     1      0
# 234152      3          5  2015-01-02   5523        698     1      0
# 234153      4          5  2015-01-02  10737       1489     1      0
# 234154      5          5  2015-01-02   4773        509     1      0
# ...       ...        ...         ...    ...        ...   ...    ...
# 235260   1111          5  2015-01-02   4653        371     1      0
# 235261   1112          5  2015-01-02   8257        758     1      0
# 235262   1113          5  2015-01-02   6005        670     1      0
# 235263   1114          5  2015-01-02  22588       3514     1      0
# 235264   1115          5  2015-01-02   7558        539     1      0
#
#        StateHoliday  SchoolHoliday
# 234150            0              1
# 234151            0              1
# 234152            0              1
# ...

# %%
# with promo 2015-01-05
promo_in_2015 = train.loc[(train["Promo"]==1) & (train["Date"]=="2015-01-05")]

# %%
promo_in_2015
# Out:
#         Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 230805      1          1  2015-01-05   6239        712     1      1
# 230806      2          1  2015-01-05   7308        755     1      1
# 230807      3          1  2015-01-05  10684        946     1      1
# 230808      4          1  2015-01-05  11177       1483     1      1
# 230809      5          1  2015-01-05   7314        749     1      1
# ...       ...        ...         ...    ...        ...   ...    ...
# 231915   1111          1  2015-01-05   7788        582     1      1
# 231916   1112          1  2015-01-05  15659       1091     1      1
# 231917   1113          1  2015-01-05   9633        877     1      1
# 231918   1114          1  2015-01-05  21350       3273     1      1
# 231919   1115          1  2015-01-05   9102        580     1      1
#
#        StateHoliday  SchoolHoliday
# 230805            0              1
# 230806            0              0
# 230807            0              1
# ...

# %%
# total sum of sales and customers without promo 2015-01-02
a = no_promo_in_2015.groupby("Date").sum().iloc[:,2:4]

# %%
# total sum of sales and customers without promo 2015-01-05
b = promo_in_2015.groupby("Date").sum().iloc[:,2:4]

# %%
combined = pd.concat([a,b])

# %%
combined
# Out:
#                Sales  Customers
# Date
# 2015-01-02   7561431     833452
# 2015-01-05  11303805    1086836

# %%
# bar chart showing the difference(in sales and customers) between 2013-01-03(NO promo) and 2013-01-07(promo)
combined.plot(kind ='bar', linewidth =2.0 )
# Out:
# <AxesSubplot:xlabel='Date'>
